# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhinandAG/AI-ML-power_output/blob/main/power_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import joblib

# %%
data=pd.read_csv("powerdata.csv")
print(data)
# Out:
#    Wind_Speed  Blade_Angle  Rotor_Speed  Power_Output
# 0           5           11          125            48
# 1           7            9          155            72
# 2           9           15          175           101
# 3          11           13          220           142
# 4          13           18          235           176

# %%
x=data[["Wind_Speed","Blade_Angle","Rotor_Speed"]]
y=data[["Power_Output"]]

model=LinearRegression()
model.fit(x,y)

print(model.coef_)
print(model.intercept_)
joblib.dump(model,"pdtrained.pkl")
# Out:
# [[1.21744659 2.41658189 0.90579858]]
# [-99.9112411]
# ['pdtrained.pkl']
